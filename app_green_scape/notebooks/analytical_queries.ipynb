# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

from queries import analytical_queries as aq

import pandas as pd

print("Módulos importados correctamente.")
# Out:
# Módulos importados correctamente.

# %%
resultados = aq.get_all_products()
df_productos = pd.DataFrame(resultados)
display(df_productos)
# Out:
# Ejecutando consulta: Listar todos los productos disponibles
# Total de productos encontrados: 99
#
# Lista de productos:
#     IDProd                        Nombre  \
# 0       25                     Aglaonema
# 1        7                     Aglaonema
# 2       47               Aglaonema Chino
# 3       10                     Aloe Vera
# 4       37                     Amaryllis
# ..     ...                           ...
# 94      96  Sistema de Riego Inteligente
# 95      67  Sistema de Riego Inteligente
# 96      34                  Tradescantia
# 97      20              Violeta Africana
# 98      35                         Yucca
#
#                                           Descripcion  Precio
# 0   Follaje atractivo, sobrevive en poca luz, vari...   23.20
# 1     Hojas grandes, variegadas, ideal para oficinas.   83.10
# 2           Follaje vistoso, tolera baja luminosidad.   65.50
# 3   Propiedades curativas, ideal para un lugar sol...    2.30
# 4           Flores impresionantes, ideal para regalo.  670.40
# ..                                                ...     ...
# 94  Automatiza el riego basado en la humedad del s...   37.91
# 95  Automatiza el riego basado en la humedad del s...  186.72
# 96  Hojas purpuras, crece rápido en condiciones hú...   46.40
# 97   Flores de colores vivos, necesita luz indirecta.    9.99
# 98         Tolerante a la sequía, prefiere sol pleno.    5.45
#
# [99 rows x 4 columns]
